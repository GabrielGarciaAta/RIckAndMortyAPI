# %% [markdown]
# ### Importando as bibliotecas necessárias

# %%
import requests
import pandas as pd
import time

# %% [markdown]
# ### Configurações iniciais

# %%
url_atual = "https://rickandmortyapi.com/api/character"
todos_os_personagens = []
pagina = 1

print("🛰️ Iniciando extração em massa...")
# Out:
# 🛰️ Iniciando extração em massa...

# %% [markdown]
# ### Loop de extração dos personagens em todas as páginas

# %%
while url_atual:
    # Requisição para a página atual
    response = requests.get(url_atual)
    data = response.json()

    # Extrai os personagens da página atual e adiciona a lista geral
    # Extend() serve pra juntar uma lista na outra 
    novos_personagens = data['results']
    todos_os_personagens.extend(novos_personagens)

    print(f"✅ Página {pagina} coletada. Total acumulado: {len(todos_os_personagens)}")

    # Pegamos o link da próxima página para o loop continuar
    url_atual = data['info']['next']
    pagina += 1

    # Pequeno intervalo para não ser bloqueado pela API
    time.sleep(0.2)

    print("\n🏁 Extração concluída")
# Out:
# ✅ Página 1 coletada. Total acumulado: 20
#
# 🏁 Extração concluída
# ✅ Página 2 coletada. Total acumulado: 40
#
# 🏁 Extração concluída
# ✅ Página 3 coletada. Total acumulado: 60
#
# 🏁 Extração concluída
# ✅ Página 4 coletada. Total acumulado: 80
#
# 🏁 Extração concluída
# ✅ Página 5 coletada. Total acumulado: 100
#
# 🏁 Extração concluída
# ✅ Página 6 coletada. Total acumulado: 120
#
# 🏁 Extração concluída
# ✅ Página 7 coletada. Total acumulado: 140
#
# 🏁 Extração concluída
# ✅ Página 8 coletada. Total acumulado: 160
#
# 🏁 Extração concluída
# ✅ Página 9 coletada. Total acumulado: 180
#
# 🏁 Extração concluída
# ✅ Página 10 coletada. Total acumulado: 200
#
# 🏁 Extração concluída
# ✅ Página 11 coletada. Total acumulado: 220
#
# 🏁 Extração concluída
# ✅ Página 12 coletada. Total acumulado: 240
#
# 🏁 Extração concluída
# ✅ Página 13 coletada. Total acumulado: 260
#
# 🏁 Extração concluída
# ✅ Página 14 coletada. Total acumulado: 280
#
# 🏁 Extração concluída
# ✅ Página 15 coletada. Total acumulado: 300
#
# 🏁 Extração concluída
# ✅ Página 16 coletada. Total acumulado: 320
#
# 🏁 Extração concluída
# ✅ Página 17 coletada. Total acumulado: 340
#
# 🏁 Extração concluída
# ✅ Página 18 coletada. Total acumulado: 360
#
# 🏁 Extração concluída
# ✅ Página 19 coletada. Total acumulado: 380
#
# 🏁 Extração concluída
# ✅ Página 20 coletada. Total acumulado: 400
#
# 🏁 Extração concluída
# ✅ Página 21 coletada. Total acumulado: 420
#
# 🏁 Extração concluída
# ✅ Página 22 coletada. Total acumulado: 440
#
# 🏁 Extração concluída
# ✅ Página 23 coletada. Total acumulado: 460
#
# 🏁 Extração concluída
# ✅ Página 24 coletada. Total acumulado: 480
#
# 🏁 Extração concluída
# ✅ Página 25 coletada. Total acumulado: 500
#
# 🏁 Extração concluída
# ✅ Página 26 coletada. Total acumulado: 520
#
# 🏁 Extração concluída
# ✅ Página 27 coletada. Total acumulado: 540
#
# 🏁 Extração concluída
# ✅ Página 28 coletada. Total acumulado: 560
#
# 🏁 Extração concluída
# ✅ Página 29 coletada. Total acumulado: 580
#
# 🏁 Extração concluída
# ✅ Página 30 coletada. Total acumulado: 600
#
# 🏁 Extração concluída
# ✅ Página 31 coletada. Total acumulado: 620
#
# 🏁 Extração concluída
# ✅ Página 32 coletada. Total acumulado: 640
#
# 🏁 Extração concluída
# ✅ Página 33 coletada. Total acumulado: 660
#
# 🏁 Extração concluída
# ✅ Página 34 coletada. Total acumulado: 680
#
# 🏁 Extração concluída
# ✅ Página 35 coletada. Total acumulado: 700
#
# 🏁 Extração concluída
# ✅ Página 36 coletada. Total acumulado: 720
#
# 🏁 Extração concluída
# ✅ Página 37 coletada. Total acumulado: 740
#
# 🏁 Extração concluída
# ✅ Página 38 coletada. Total acumulado: 760
#
# 🏁 Extração concluída
# ✅ Página 39 coletada. Total acumulado: 780
#
# 🏁 Extração concluída
# ✅ Página 40 coletada. Total acumulado: 800
#
# 🏁 Extração concluída
# ✅ Página 41 coletada. Total acumulado: 820
#
# 🏁 Extração concluída
# ✅ Página 42 coletada. Total acumulado: 826
#
# 🏁 Extração concluída

# %% [markdown]
# ### Criação do dataframe

# %%
# Criando o dataframe geral e normalizando
df_completo_bruto = pd.json_normalize(todos_os_personagens)

# Seleção apenas das colunas importantes (para mim)
colunas_interesse = [
    'id', 'name', 'status', 'species', 'type', 'gender',
     'origin.name', 'location.name', 'image'
]

df_final = df_completo_bruto[colunas_interesse].copy()

# Renomeando para o português
df_final.columns = [
    'id', 'nome', 'status', 'especie', 'tipo', 'genero',
    'origem', 'localizacao', 'url_foto'   
]

print(f"Tamanho Final da tabela: {df_final.shape[0]} linhas e {df_final.shape[1]} colunas.")
display(df_final.head())
# Out:
# Tamanho Final da tabela: 826 linhas e 9 colunas.
#    id          nome status especie tipo  genero  \
# 0   1  Rick Sanchez  Alive   Human         Male
# 1   2   Morty Smith  Alive   Human         Male
# 2   3  Summer Smith  Alive   Human       Female
# 3   4    Beth Smith  Alive   Human       Female
# 4   5   Jerry Smith  Alive   Human         Male
#
#                           origem                    localizacao  \
# 0                  Earth (C-137)               Citadel of Ricks
# 1                        unknown               Citadel of Ricks
# 2  Earth (Replacement Dimension)  Earth (Replacement Dimension)
# 3  Earth (Replacement Dimension)  Earth (Replacement Dimension)
# 4  Earth (Replacement Dimension)  Earth (Replacement Dimension)
#
#                                             url_foto
# 0  https://rickandmortyapi.com/api/character/avat...
# 1  https://rickandmortyapi.com/api/character/avat...
# 2  https://rickandmortyapi.com/api/character/avat...
# 3  https://rickandmortyapi.com/api/character/avat...
# 4  https://rickandmortyapi.com/api/character/avat...

# %% [markdown]
# ### Transformação do DF em arquivo CSV

# %%
df_final.to_csv('../data/todos_personagens_rick_morty.csv', index=False, sep=';', encoding='utf-8')
print("💾 Arquivo CSV completo gerado na pasta/data!")
# Out:
# 💾 Arquivo CSV completo gerado na pasta/data!
